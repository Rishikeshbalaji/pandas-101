# %%
import pandas as pd
import numpy as np

# %%
# Read the student csv
df=pd.read_csv('student_data.csv',sep = ';')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# read all types of students_dataset in data set and get each colom
# get describe for each colom
print(df.notnull)
print(df.dtypes)
# Out:
# <bound method DataFrame.notnull of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# get discribe for each colom
df.describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False)
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df['age'].max()
# Out:
# 22

# %%
# group n tell me the number of datas in the data for each chool
print(df.groupby("school").count())
# alternatove
print(df.value_counts('school'))
# alternatove
df.pivot_table(index='school', aggfunc='count')
# Out:
#         sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  \
# school
# GP      349  349      349      349      349   349   349   349   349     349
# MS       46   46       46       46       46    46    46    46    46      46
#
#         ...  famrel  freetime  goout  Dalc  Walc  health  absences   G1   G2  \
# school  ...
# GP      ...     349       349    349   349   349     349       349  349  349
# MS      ...      46        46     46    46    46      46        46   46   46
#
#          G3
# school
# GP      349
# MS       46
#
# [2 rows x 32 columns]
# school
# GP    349
# MS     46
# dtype: int64
#         Dalc  Fedu  Fjob   G1   G2   G3  Medu  Mjob  Pstatus  Walc  ...  \
# school                                                              ...
# GP       349   349   349  349  349  349   349   349      349   349  ...
# MS        46    46    46   46   46   46    46    46       46    46  ...
#
# ...

# %%
# for each school give me male and fmale count 
print(df.groupby(["school",'sex'])['sex'].count())
# Out:
# school  sex
# GP      F      183
#         M      166
# MS      F       25
#         M       21
# Name: sex, dtype: int64

# %%
# What is the range of age in this dataset
print(df['age'].max()-df['age'].min())
# Out:
# 7

# %%
# How many males and how many females are there
df['sex'].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
# What is the distribution of Mjob column
df['Mjob'].value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %%
# Create a age bracket <20 and >20 and then tell me number or counts for each of this class
def divide_age(age):
    if age<20:
        return'cat-1'
    elif age<20:
        return'cat-2'
    divide_age(100)
df['age'].apply(divide_age).value_count()

# %%
# What is the range of age in this dataset
# How many males and how many females are there
# What is the distribution of Mjob column
# Per school how many males and females are there
# Create a age bracket <20 and >20 and then tell me number or counts for each of this class
# What is the average age of males and females
# Sort the data by age and tell is the youngest person male or female.

# %%
# What is the average age of males and females
avg_age = df.groupby(by='age').age.mean()
avg_age

# %%
# Sort the data by age and tell is the youngest person male or female.
print(df[df['age']==df['age'].min()])
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 147     GP   F   15       U     GT3       T     1     2   at_home     other
# 149     GP   M   15       U     LE3       A     2     1  services     other
# 152     GP   F   15       R     GT3       T     3     3  services  services
# 155     GP   M   15       R     GT3       T     2     3   at_home  services
# 161     GP   M   15       R     GT3       T     3     2     other     other
#
# ...
